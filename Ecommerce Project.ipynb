# %% [markdown]
# Importing the required Libraries

# %%
import pandas as pd
import plotly as plx
import plotly.io as pio
import numpy  as np
import seaborn as sns
from scipy import stats
# %matplotlib inline
sns.set(rc={'figure.figsize': [10, 10]}, font_scale=1.3)
pd.set_option('mode.chained_assignment', None)

# %% [markdown]
# Reading the Data

# %%
df = pd.read_csv("List of Orders.csv")
df1 = pd.read_csv("Order Details.csv")

# %%
df.head()
# Out:
#   Order ID  Order Date CustomerName           State       City
# 0  B-25601  01-04-2018       Bharat         Gujarat  Ahmedabad
# 1  B-25602  01-04-2018        Pearl     Maharashtra       Pune
# 2  B-25603  03-04-2018        Jahan  Madhya Pradesh     Bhopal
# 3  B-25604  03-04-2018       Divsha       Rajasthan     Jaipur
# 4  B-25605  05-04-2018      Kasheen     West Bengal    Kolkata

# %% [markdown]
# Merging the Data to get orders Dataframe

# %%
orders = pd.merge(df1,df,how ="left", on = "Order ID" )

# %%
orders.head()
# Out:
#   Order ID  Amount  Profit  Quantity     Category      Sub-Category  \
# 0  B-25601  1275.0 -1148.0         7    Furniture         Bookcases
# 1  B-25601    66.0   -12.0         5     Clothing             Stole
# 2  B-25601     8.0    -2.0         3     Clothing       Hankerchief
# 3  B-25601    80.0   -56.0         4  Electronics  Electronic Games
# 4  B-25602   168.0  -111.0         2  Electronics            Phones
#
#    Order Date CustomerName        State       City
# 0  01-04-2018       Bharat      Gujarat  Ahmedabad
# 1  01-04-2018       Bharat      Gujarat  Ahmedabad
# 2  01-04-2018       Bharat      Gujarat  Ahmedabad
# 3  01-04-2018       Bharat      Gujarat  Ahmedabad
# 4  01-04-2018        Pearl  Maharashtra       Pune

# %%
orders.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1500 entries, 0 to 1499
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Order ID      1500 non-null   object
#  1   Amount        1500 non-null   float64
#  2   Profit        1500 non-null   float64
#  3   Quantity      1500 non-null   int64
#  4   Category      1500 non-null   object
#  5   Sub-Category  1500 non-null   object
#  6   Order Date    1500 non-null   object
#  7   CustomerName  1500 non-null   object
#  8   State         1500 non-null   object
#  9   City          1500 non-null   object
# dtypes: float64(2), int64(1), object(7)
# memory usage: 117.3+ KB

# %% [markdown]
# Exploratory Data Analysis and Data Preprocessing

# %%
orders.describe()
# Out:
#             Amount       Profit     Quantity
# count  1500.000000  1500.000000  1500.000000
# mean    287.668000    15.970000     3.743333
# std     461.050488   169.140565     2.184942
# min       4.000000 -1981.000000     1.000000
# 25%      45.000000    -9.250000     2.000000
# 50%     118.000000     9.000000     3.000000
# 75%     322.000000    38.000000     5.000000
# max    5729.000000  1698.000000    14.000000

# %%
orders.describe(include = "O")
# Out:
#        Order ID  Category Sub-Category  Order Date CustomerName  \
# count      1500      1500         1500        1500         1500
# unique      500         3           17         307          332
# top     B-25656  Clothing        Saree  10-03-2019     Abhishek
# freq         12       949          210          33           25
#
#                  State    City
# count             1500    1500
# unique              19      24
# top     Madhya Pradesh  Indore
# freq               340     267

# %%
orders.isnull().sum()
# Out:
# Order ID        0
# Amount          0
# Profit          0
# Quantity        0
# Category        0
# Sub-Category    0
# Order Date      0
# CustomerName    0
# State           0
# City            0
# dtype: int64

# %%
orders.columns
# Out:
# Index(['Order ID', 'Amount', 'Profit', 'Quantity', 'Category', 'Sub-Category',
#        'Order Date', 'CustomerName', 'State', 'City'],
#       dtype='object')

# %%
new_coulmns = orders.columns.str.replace(" ","-")
new_coulmns1 = new_coulmns.str.replace("CustomerName","Customer-Name")
new_coulmns1
# Out:
# Index(['Order-ID', 'Amount', 'Profit', 'Quantity', 'Category', 'Sub-Category',
#        'Order-Date', 'Customer-Name', 'State', 'City'],
#       dtype='object')

# %%
orders.columns = new_coulmns1

# %%
orders.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1500 entries, 0 to 1499
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Order-ID       1500 non-null   object
#  1   Amount         1500 non-null   float64
#  2   Profit         1500 non-null   float64
#  3   Quantity       1500 non-null   int64
#  4   Category       1500 non-null   object
#  5   Sub-Category   1500 non-null   object
#  6   Order-Date     1500 non-null   object
#  7   Customer-Name  1500 non-null   object
#  8   State          1500 non-null   object
#  9   City           1500 non-null   object
# dtypes: float64(2), int64(1), object(7)
# memory usage: 117.3+ KB

# %%
orders.columns
# Out:
# Index(['Order-ID', 'Amount', 'Profit', 'Quantity', 'Category', 'Sub-Category',
#        'Order-Date', 'Customer-Name', 'State', 'City'],
#       dtype='object')

# %% [markdown]
# Extracting the Day, Month and Year

# %%
orders["Day"] = orders["Order-Date"].apply(lambda x : x.split("-")[0])
orders["Month"] = orders["Order-Date"].apply(lambda x : x.split("-")[1])
orders["Year"] = orders["Order-Date"].apply(lambda x : x.split("-")[2])
orders.drop(["Order-Date"],axis=1,inplace=True)

# %%
orders.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1500 entries, 0 to 1499
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Order-ID       1500 non-null   object
#  1   Amount         1500 non-null   float64
#  2   Profit         1500 non-null   float64
#  3   Quantity       1500 non-null   int64
#  4   Category       1500 non-null   object
#  5   Sub-Category   1500 non-null   object
#  6   Customer-Name  1500 non-null   object
#  7   State          1500 non-null   object
#  8   City           1500 non-null   object
#  9   Day            1500 non-null   object
#  10  Month          1500 non-null   object
#  11  Year           1500 non-null   object
# dtypes: float64(2), int64(1), object(9)
# memory usage: 140.8+ KB

# %%
orders["Month"]=orders["Month"].astype(int)

# %%
orders.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1500 entries, 0 to 1499
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Order-ID       1500 non-null   object
#  1   Amount         1500 non-null   float64
#  2   Profit         1500 non-null   float64
#  3   Quantity       1500 non-null   int64
#  4   Category       1500 non-null   object
#  5   Sub-Category   1500 non-null   object
#  6   Customer-Name  1500 non-null   object
#  7   State          1500 non-null   object
#  8   City           1500 non-null   object
#  9   Day            1500 non-null   object
#  10  Month          1500 non-null   int32
#  11  Year           1500 non-null   object
# dtypes: float64(2), int32(1), int64(1), object(8)
# memory usage: 134.9+ KB

# %%
orders["Month"].value_counts()
# Out:
# Month
# 3     205
# 1     192
# 11    159
# 2     140
# 8     120
# 5     118
# 12    111
# 10    106
# 4     101
# 6     101
# 9      83
# 7      64
# Name: count, dtype: int64

# %% [markdown]
# Mapping Month Names to the Month value

# %%
month_map = {1:'Jan',2:'Feb',3:"Mar", 4:'Apr',5:"May",6:'Jun',7:'Jul',8:'Aug',9:"Sep",10:'Oct',11:'Nov',12:'Dec'}

orders["Month"] = orders["Month"].map(month_map)
orders
# Out:
#      Order-ID  Amount  Profit  Quantity     Category      Sub-Category  \
# 0     B-25601  1275.0 -1148.0         7    Furniture         Bookcases
# 1     B-25601    66.0   -12.0         5     Clothing             Stole
# 2     B-25601     8.0    -2.0         3     Clothing       Hankerchief
# 3     B-25601    80.0   -56.0         4  Electronics  Electronic Games
# 4     B-25602   168.0  -111.0         2  Electronics            Phones
# ...       ...     ...     ...       ...          ...               ...
# 1495  B-26099   835.0   267.0         5  Electronics            Phones
# 1496  B-26099  2366.0   552.0         5     Clothing          Trousers
# 1497  B-26100   828.0   230.0         2    Furniture            Chairs
# 1498  B-26100    34.0    10.0         2     Clothing           T-shirt
# 1499  B-26100    72.0    16.0         2     Clothing             Shirt
#
#      Customer-Name           State       City Day Month  Year
# 0           Bharat         Gujarat  Ahmedabad  01   Apr  2018
# 1           Bharat         Gujarat  Ahmedabad  01   Apr  2018
# 2           Bharat         Gujarat  Ahmedabad  01   Apr  2018
# 3           Bharat         Gujarat  Ahmedabad  01   Apr  2018
# 4            Pearl     Maharashtra       Pune  01   Apr  2018
# ...            ...             ...        ...  ..   ...   ...
# 1495        Bhishm     Maharashtra     Mumbai  30   Mar  2019
# 1496        Bhishm     Maharashtra     Mumbai  30   Mar  2019
# 1497        Hitika  Madhya Pradesh     Indore  31   Mar  2019
# 1498        Hitika  Madhya Pradesh     Indore  31   Mar  2019
# 1499        Hitika  Madhya Pradesh     Indore  31   Mar  2019
#
# [1500 rows x 12 columns]

# %%
orders["Month"].value_counts()
# Out:
# Month
# Mar    205
# Jan    192
# Nov    159
# Feb    140
# Aug    120
# May    118
# Dec    111
# Oct    106
# Apr    101
# Jun    101
# Sep     83
# Jul     64
# Name: count, dtype: int64

# %%
orders["Profit"] = orders["Profit"].abs()

# %%
orders
# Out:
#      Order-ID  Amount  Profit  Quantity     Category      Sub-Category  \
# 0     B-25601  1275.0  1148.0         7    Furniture         Bookcases
# 1     B-25601    66.0    12.0         5     Clothing             Stole
# 2     B-25601     8.0     2.0         3     Clothing       Hankerchief
# 3     B-25601    80.0    56.0         4  Electronics  Electronic Games
# 4     B-25602   168.0   111.0         2  Electronics            Phones
# ...       ...     ...     ...       ...          ...               ...
# 1495  B-26099   835.0   267.0         5  Electronics            Phones
# 1496  B-26099  2366.0   552.0         5     Clothing          Trousers
# 1497  B-26100   828.0   230.0         2    Furniture            Chairs
# 1498  B-26100    34.0    10.0         2     Clothing           T-shirt
# 1499  B-26100    72.0    16.0         2     Clothing             Shirt
#
#      Customer-Name           State       City Day Month  Year
# 0           Bharat         Gujarat  Ahmedabad  01   Apr  2018
# 1           Bharat         Gujarat  Ahmedabad  01   Apr  2018
# 2           Bharat         Gujarat  Ahmedabad  01   Apr  2018
# 3           Bharat         Gujarat  Ahmedabad  01   Apr  2018
# 4            Pearl     Maharashtra       Pune  01   Apr  2018
# ...            ...             ...        ...  ..   ...   ...
# 1495        Bhishm     Maharashtra     Mumbai  30   Mar  2019
# 1496        Bhishm     Maharashtra     Mumbai  30   Mar  2019
# 1497        Hitika  Madhya Pradesh     Indore  31   Mar  2019
# 1498        Hitika  Madhya Pradesh     Indore  31   Mar  2019
# 1499        Hitika  Madhya Pradesh     Indore  31   Mar  2019
#
# [1500 rows x 12 columns]

# %% [markdown]
# Getting the top purchaser customers

# %%
Top_purchaser = orders.groupby(['Customer-Name'])[["Amount","Quantity"]].sum().sort_values(by ="Amount", ascending=False).head(10)
Top_purchaser
# Out:
#                Amount  Quantity
# Customer-Name
# Yaanvi         9177.0        71
# Pooja          9030.0        57
# Abhishek       8135.0        89
# Surabhi        6889.0        55
# Soumya         6869.0        58
# Harshal        6026.0        25
# Priyanka       5762.0        79
# Shruti         5750.0        67
# Abhijeet       5691.0        45
# Sarita         5449.0        50

# %% [markdown]
# Getting the top sold Categories

# %%
Top_selling_categories = orders.groupby(["Category"])[["Quantity","Amount","Profit"]].sum()
Top_selling_categories
# Out:
#              Quantity    Amount   Profit
# Category
# Clothing         3516  139054.0  35149.0
# Electronics      1154  165267.0  43938.0
# Furniture         945  127181.0  33340.0

# %% [markdown]
# Getting the most Profitable sub-category

# %%
Top_profitable_subcategories = orders.groupby(["Category","Sub-Category"])[["Quantity","Amount","Profit"]].sum().sort_values(by="Profit",ascending=False).reset_index()
Top_profitable_subcategories
# Out:
#        Category      Sub-Category  Quantity   Amount   Profit
# 0     Furniture         Bookcases       297  56861.0  15532.0
# 1   Electronics          Printers       291  58252.0  14690.0
# 2      Clothing             Saree       782  53511.0  14420.0
# 3   Electronics            Phones       304  46119.0  13169.0
# 4   Electronics  Electronic Games       297  39168.0   9906.0
# 5     Furniture            Chairs       277  34222.0   7585.0
# 6     Furniture            Tables        61  22614.0   6363.0
# 7   Electronics       Accessories       262  21728.0   6173.0
# 8      Clothing          Trousers       135  30039.0   5649.0
# 9      Clothing             Stole       671  18546.0   5133.0
# 10     Clothing       Hankerchief       754  14608.0   4044.0
# 11    Furniture       Furnishings       310  13484.0   3860.0
# 12     Clothing           T-shirt       305   7382.0   1884.0
# 13     Clothing             Shirt       271   7555.0   1865.0
# 14     Clothing             Kurti       164   3361.0   1007.0
# 15     Clothing          Leggings       186   2106.0    604.0
# 16     Clothing             Skirt       248   1946.0    543.0

# %%
orders.columns
# Out:
# Index(['Order-ID', 'Amount', 'Profit', 'Quantity', 'Category', 'Sub-Category',
#        'Customer-Name', 'State', 'City', 'Day', 'Month', 'Year'],
#       dtype='object')

# %%
sales_per_year = orders.groupby(["Year","Month","Category"])[["Quantity","Amount","Profit"]].sum().sort_values(by="Profit",ascending=False).reset_index()
sales_per_year
# Out:
#     Year Month     Category  Quantity   Amount  Profit
# 0   2019   Jan  Electronics       164  26716.0  5923.0
# 1   2019   Mar     Clothing       516  21418.0  5456.0
# 2   2019   Jan    Furniture       145  21257.0  4964.0
# 3   2019   Mar  Electronics       141  20860.0  4940.0
# 4   2019   Feb  Electronics        82  12593.0  4671.0
# 5   2018   Nov  Electronics       105  16651.0  4120.0
# 6   2018   Sep    Furniture        83   8704.0  3990.0
# 7   2018   Apr    Furniture        63   8121.0  3981.0
# 8   2018   May  Electronics       116  12807.0  3981.0
# 9   2018   Nov    Furniture        93  15165.0  3945.0
# 10  2018   Oct  Electronics        85  13361.0  3785.0
# 11  2018   Nov     Clothing       380  16270.0  3778.0
# 12  2018   Apr  Electronics        75  11127.0  3699.0
# 13  2018   Dec  Electronics       110  18560.0  3450.0
# 14  2018   Jun     Clothing       235   8782.0  3330.0
# 15  2018   Aug    Furniture        72   9538.0  3315.0
# 16  2018   Sep     Clothing       192  10717.0  3179.0
# 17  2019   Jan     Clothing       436  13466.0  3049.0
# 18  2018   Oct    Furniture        50   6766.0  2904.0
# 19  2018   Oct     Clothing       284  11488.0  2842.0
# 20  2018   Aug     Clothing       276  11822.0  2841.0
# 21  2018   Apr     Clothing       251  13478.0  2826.0
# 22  2019   Mar    Furniture        94  16659.0  2679.0
# 23  2018   May     Clothing       233   9518.0  2659.0
# 24  2018   Jun  Electronics        82   9344.0  2580.0
# 25  2018   Aug  Electronics        98   9539.0  2510.0
# 26  2018   Jul  Electronics        40   6502.0  2495.0
# 27  2019   Feb    Furniture       118  16262.0  2322.0
# 28  2019   Feb     Clothing       312   9569.0  2310.0
# 29  2018   Dec     Clothing       259   9545.0  1923.0
# 30  2018   Sep  Electronics        56   7207.0  1784.0
# 31  2018   Dec    Furniture        43   9474.0  1657.0
# 32  2018   May    Furniture        74   6220.0  1602.0
# 33  2018   Jun    Furniture        52   5532.0  1122.0
# 34  2018   Jul     Clothing       142   2981.0   956.0
# 35  2018   Jul    Furniture        58   3483.0   859.0

# %% [markdown]
# Average order value and profit

# %%
Average_order_value = orders["Amount"].sum()/orders["Order-ID"].nunique()
Average_order_value
# Out:
# 863.004

# %%
Average_order_profit = orders["Profit"].sum()/orders["Order-ID"].nunique()
Average_order_profit
# Out:
# 224.854

# %%
orders.head()
# Out:
#   Order-ID  Amount  Profit  Quantity     Category      Sub-Category  \
# 0  B-25601  1275.0  1148.0         7    Furniture         Bookcases
# 1  B-25601    66.0    12.0         5     Clothing             Stole
# 2  B-25601     8.0     2.0         3     Clothing       Hankerchief
# 3  B-25601    80.0    56.0         4  Electronics  Electronic Games
# 4  B-25602   168.0   111.0         2  Electronics            Phones
#
#   Customer-Name        State       City Day Month  Year
# 0        Bharat      Gujarat  Ahmedabad  01   Apr  2018
# 1        Bharat      Gujarat  Ahmedabad  01   Apr  2018
# 2        Bharat      Gujarat  Ahmedabad  01   Apr  2018
# 3        Bharat      Gujarat  Ahmedabad  01   Apr  2018
# 4         Pearl  Maharashtra       Pune  01   Apr  2018

# %% [markdown]
# The most Profitable Categories

# %%
Profit_per_categories = orders.groupby(["Category","Sub-Category"])[["Quantity","Amount","Profit"]].sum().sort_values(by="Profit",ascending=False).reset_index()
Profit_per_categories
# Out:
#        Category      Sub-Category  Quantity   Amount   Profit
# 0     Furniture         Bookcases       297  56861.0  15532.0
# 1   Electronics          Printers       291  58252.0  14690.0
# 2      Clothing             Saree       782  53511.0  14420.0
# 3   Electronics            Phones       304  46119.0  13169.0
# 4   Electronics  Electronic Games       297  39168.0   9906.0
# 5     Furniture            Chairs       277  34222.0   7585.0
# 6     Furniture            Tables        61  22614.0   6363.0
# 7   Electronics       Accessories       262  21728.0   6173.0
# 8      Clothing          Trousers       135  30039.0   5649.0
# 9      Clothing             Stole       671  18546.0   5133.0
# 10     Clothing       Hankerchief       754  14608.0   4044.0
# 11    Furniture       Furnishings       310  13484.0   3860.0
# 12     Clothing           T-shirt       305   7382.0   1884.0
# 13     Clothing             Shirt       271   7555.0   1865.0
# 14     Clothing             Kurti       164   3361.0   1007.0
# 15     Clothing          Leggings       186   2106.0    604.0
# 16     Clothing             Skirt       248   1946.0    543.0

# %% [markdown]
# Visulaization
# Univariant analysis
#  The variable of concerin is the profit

# %%
import plotly.express as px
import plotly.figure_factory as ff

# %%
px.histogram(orders, x= orders["Profit"])

# %% [markdown]
# Detecting the skewness and remove it by log transformation

# %%
orders["Profit"].skew()
# Out:
# 5.691747983660514

# %%
orders["Profit-log"]= np.log1p(orders["Profit"])

# %%
orders["Profit-log"].skew()
# Out:
# 0.008105252522666957

# %%
px.histogram(orders, x= orders["Profit-log"],color="Year")

# %%
px.box(orders, x= orders["Profit-log"],color="Year")

# %%
px.box(orders, x= orders["Profit"],color="Year")

# %%
px.histogram(orders, x= orders["Year"], color = "Category")

# %%
fig = px.histogram(orders, x="Year", y="Profit-log", color="Category")       
fig.show()

# %%
profit = orders["Profit-log"].to_list()
ff.create_distplot([profit], ["Profit-log"], bin_size=2, show_rug=True)

# %%
profit_1 = orders["Profit-log"].to_list()
ff.create_distplot([profit_1], ["Profit-log"], bin_size=2, show_rug=True)

# %%
profit_1 = orders["Profit-log"].to_list()
ff.create_distplot([profit_1], ["Profit-log"], bin_size=2, show_rug=False,show_hist=False)

# %%
profit = orders["Profit-log"].to_list()
ff.create_distplot([profit], ["Profit-log"], bin_size=2, show_rug=False,show_hist=False)
fig.update_xaxes(title_text="Profit")
fig.update_yaxes(title_text="Frequency")
fig.show()

# %% [markdown]
# Bivarient Visualization

# %%
px.scatter(orders,x="Profit",y="Amount",color ="Year")

# %%
px.scatter(orders,x="Amount",y="Profit",color ="Year")

# %%
px.scatter(orders,x="Profit",y="Amount",marginal_x="violin",marginal_y="box",color = "Category")

# %%
px.scatter(orders,x="Profit",y="Amount",marginal_x="violin",marginal_y="box",color = "Year")

# %%
px.scatter_matrix(orders, dimensions=['Profit', 'Amount', 'Quantity'], color='Year')

# %%
type (sales_per_year)
# Out:
# pandas.core.frame.DataFrame

# %%
px.bar(orders, x='Year', y= "Profit", color = "Year")

# %% [markdown]
# Dealing with Outliers

# %%
px.box(orders, x= orders["Profit-log"])

# %%
px.box(orders, x= orders["Profit"])

# %%
from datasist.structdata import detect_outliers

# %%
orders.head()
# Out:
#   Order-ID  Amount  Profit  Quantity     Category      Sub-Category  \
# 0  B-25601  1275.0  1148.0         7    Furniture         Bookcases
# 1  B-25601    66.0    12.0         5     Clothing             Stole
# 2  B-25601     8.0     2.0         3     Clothing       Hankerchief
# 3  B-25601    80.0    56.0         4  Electronics  Electronic Games
# 4  B-25602   168.0   111.0         2  Electronics            Phones
#
#   Customer-Name        State       City Day Month  Year  Profit-log
# 0        Bharat      Gujarat  Ahmedabad  01   Apr  2018    7.046647
# 1        Bharat      Gujarat  Ahmedabad  01   Apr  2018    2.564949
# 2        Bharat      Gujarat  Ahmedabad  01   Apr  2018    1.098612
# 3        Bharat      Gujarat  Ahmedabad  01   Apr  2018    4.043051
# 4         Pearl  Maharashtra       Pune  01   Apr  2018    4.718499

# %%
orders.isnull().sum()
# Out:
# Order-ID         0
# Amount           0
# Profit           0
# Quantity         0
# Category         0
# Sub-Category     0
# Customer-Name    0
# State            0
# City             0
# Day              0
# Month            0
# Year             0
# Profit-log       0
# dtype: int64

# %%
orders.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1500 entries, 0 to 1499
# Data columns (total 13 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Order-ID       1500 non-null   object
#  1   Amount         1500 non-null   float64
#  2   Profit         1500 non-null   float64
#  3   Quantity       1500 non-null   int64
#  4   Category       1500 non-null   object
#  5   Sub-Category   1500 non-null   object
#  6   Customer-Name  1500 non-null   object
#  7   State          1500 non-null   object
#  8   City           1500 non-null   object
#  9   Day            1500 non-null   object
#  10  Month          1500 non-null   object
#  11  Year           1500 non-null   object
#  12  Profit-log     1500 non-null   float64
# dtypes: float64(3), int64(1), object(9)
# memory usage: 152.5+ KB

# %%
orders.head()
# Out:
#   Order-ID  Amount  Profit  Quantity     Category      Sub-Category  \
# 0  B-25601  1275.0  1148.0         7    Furniture         Bookcases
# 1  B-25601    66.0    12.0         5     Clothing             Stole
# 2  B-25601     8.0     2.0         3     Clothing       Hankerchief
# 3  B-25601    80.0    56.0         4  Electronics  Electronic Games
# 4  B-25602   168.0   111.0         2  Electronics            Phones
#
#   Customer-Name        State       City Day Month  Year  Profit-log
# 0        Bharat      Gujarat  Ahmedabad  01   Apr  2018    7.046647
# 1        Bharat      Gujarat  Ahmedabad  01   Apr  2018    2.564949
# 2        Bharat      Gujarat  Ahmedabad  01   Apr  2018    1.098612
# 3        Bharat      Gujarat  Ahmedabad  01   Apr  2018    4.043051
# 4         Pearl  Maharashtra       Pune  01   Apr  2018    4.718499

# %%
from datasist.structdata import detect_outliers
outliers_indices = detect_outliers(orders,0,orders["Profit-log"])
len(outliers_indices)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\phmah\Python 3\Lib\site-packages\pandas\core\indexes\base.py:3790, in Index.get_loc(self, key)
#    3789 try:
# -> 3790     return self._engine.get_loc(casted_key)
#    3791 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 7.046647277848756
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# d:\Epsilon AI\Mid-Project\Ecommerce Project.ipynb Cell 76 line 2
#       <a href='vscode-notebook-cell:/d%3A/Epsilon%20AI/Mid-Project/Ecommerce%20Project.ipynb#Y135sZmlsZQ%3D%3D?line=0'>1</a> from datasist.structdata import detect_outliers
# ----> <a href='vscode-notebook-cell:/d%3A/Epsilon%20AI/Mid-Project/Ecommerce%20Project.ipynb#Y135sZmlsZQ%3D%3D?line=1'>2</a> outliers_indices = detect_outliers(orders,0,orders["Profit-log"])
#       <a href='vscode-notebook-cell:/d%3A/Epsilon%20AI/Mid-Project/Ecommerce%20Project.ipynb#Y135sZmlsZQ%3D%3D?line=2'>3</a> len(outliers_indices)
#
# File c:\Users\phmah\Python 3\Lib\site-packages\datasist\structdata.py:365, in detect_outliers(data, n, features)
#     362 # iterate over features(columns)
#     363 for col in features:
#     364     # 1st quartile (25%)
# --> 365     Q1 = np.percentile(data[col], 25)
#     366     # 3rd quartile (75%)
#     367     Q3 = np.percentile(data[col], 75)
#
# File c:\Users\phmah\Python 3\Lib\site-packages\pandas\core\frame.py:3896, in DataFrame.__getitem__(self, key)
#    3894 if self.columns.nlevels > 1:
#    3895     return self._getitem_multilevel(key)
# -> 3896 indexer = self.columns.get_loc(key)
#    3897 if is_integer(indexer):
#    3898     indexer = [indexer]
#
# File c:\Users\phmah\Python 3\Lib\site-packages\pandas\core\indexes\base.py:3797, in Index.get_loc(self, key)
#    3792     if isinstance(casted_key, slice) or (
#    3793         isinstance(casted_key, abc.Iterable)
#    3794         and any(isinstance(x, slice) for x in casted_key)
#    3795     ):
#    3796         raise InvalidIndexError(key)
# -> 3797     raise KeyError(key) from err
#    3798 except TypeError:
#    3799     # If we have a listlike key, _check_indexing_error will raise
#    3800     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3801     #  the TypeError.
#    3802     self._check_indexing_error(key)
#
# KeyError: 7.046647277848756

# %% [markdown]
# Dealing With Categorical Data

# %%
orders= pd.get_dummies(orders,columns = ["Category","Sub-Category"])

# %%
orders.head()
# Out:
#   Order-ID  Amount  Profit  Quantity Customer-Name        State       City  \
# 2  B-25601     8.0     2.0         3        Bharat      Gujarat  Ahmedabad
# 3  B-25601    80.0    56.0         4        Bharat      Gujarat  Ahmedabad
# 4  B-25602   168.0   111.0         2         Pearl  Maharashtra       Pune
# 5  B-25602   424.0   272.0         5         Pearl  Maharashtra       Pune
# 6  B-25602  2617.0  1151.0         4         Pearl  Maharashtra       Pune
#
#   Day Month  Year  ...  Sub-Category_Leggings  Sub-Category_Phones  \
# 2  01   Apr  2018  ...                  False                False
# 3  01   Apr  2018  ...                  False                False
# 4  01   Apr  2018  ...                  False                 True
# 5  01   Apr  2018  ...                  False                 True
# 6  01   Apr  2018  ...                  False                 True
#
#    Sub-Category_Printers  Sub-Category_Saree  Sub-Category_Shirt  \
# 2                  False               False               False
# 3                  False               False               False
# 4                  False               False               False
# 5                  False               False               False
# 6                  False               False               False
#
#    Sub-Category_Skirt  Sub-Category_Stole  Sub-Category_T-shirt  \
# 2               False               False                 False
# 3               False               False                 False
# 4               False               False                 False
# 5               False               False                 False
# 6               False               False                 False
#
#    Sub-Category_Tables  Sub-Category_Trousers
# 2                False                  False
# 3                False                  False
# 4                False                  False
# 5                False                  False
# 6                False                  False
#
# [5 rows x 31 columns]

# %% [markdown]
# Split the Data to train and test

# %%
from sklearn.model_selection import train_test_split
x = orders.drop("Profit-log",axis = 1)
y = orders["Profit-log"]


x_train,x_test, y_train, y_test = train_test_split(x,y, test_size=0.2)

# %%
x.columns
# Out:
# Index(['Order-ID', 'Amount', 'Profit', 'Quantity', 'Customer-Name', 'State',
#        'City', 'Day', 'Month', 'Year', 'Category_Clothing',
#        'Category_Electronics', 'Category_Furniture',
#        'Sub-Category_Accessories', 'Sub-Category_Bookcases',
#        'Sub-Category_Chairs', 'Sub-Category_Electronic Games',
#        'Sub-Category_Furnishings', 'Sub-Category_Hankerchief',
#        'Sub-Category_Kurti', 'Sub-Category_Leggings', 'Sub-Category_Phones',
#        'Sub-Category_Printers', 'Sub-Category_Saree', 'Sub-Category_Shirt',
#        'Sub-Category_Skirt', 'Sub-Category_Stole', 'Sub-Category_T-shirt',
#        'Sub-Category_Tables', 'Sub-Category_Trousers'],
#       dtype='object')
